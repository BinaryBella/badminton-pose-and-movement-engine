# %%
# !pip install -q huggingface_hub

from huggingface_hub import login
login()  # paste your write token when prompted
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>C5NO-YYZD</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>chathushik</b> (token: <code>oauth-chathushik</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

model_path = hf_hub_download(
    repo_id="chathushik/forensicnet-badminton-pose",
    filename="best.pt"
)
model = YOLO(model_path)
print("✅ Model loaded:", model_path)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# best.pt:   0%|          | 0.00/53.3M [00:00<?, ?B/s]
# ✅ Model loaded: /root/.cache/huggingface/hub/models--chathushik--forensicnet-badminton-pose/snapshots/070c8a377efdad86575487110660491513d36a4b/best.pt
